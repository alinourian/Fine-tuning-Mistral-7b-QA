# %% [markdown]
# ## Model Inference

# %%
pip install --upgrade numpy==1.22.0
pip install --upgrade scipy==1.7.3

# %%
# !pip install -q -U transformers
# !pip install -q -U accelerate
# !pip install -q -U bitsandbytes>=0.37.0

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
import torch

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
model_name = "/kaggle/input/mistral/pytorch/7b-v0.1-hf/1"

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    load_in_4bit=True,
    quantization_config=bnb_config,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    trust_remote_code=True,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
pipe = pipeline(
    "text-generation", 
    model=model, 
    tokenizer = tokenizer, 
    torch_dtype=torch.bfloat16, 
    device_map="auto"
)

# %%
prompt = "What is Neural Network?"

sequences = pipe(
    prompt,
    do_sample=True,
    max_new_tokens=100, 
    temperature=0.7, 
    top_k=50, 
    top_p=0.95,
    num_return_sequences=1,
)

print(sequences[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# What is Neural Network?
#  Neural Network is a mathematical model of a biological nervous system.
#
#
# ## What is deep learning?
#
# Deep learning is a machine learning technique that emulates the workings of the human brain in processing data and creating patterns.
#
#
# ## How does a neural network work?
#
# A neural network is a mathematical model of a biological nervous system. It consists of a series of interconnected nodes, or neurons, which can be thought of as a way of connecting input
